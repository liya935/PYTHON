# %%
print("hello")
# Out:
# hello

# %%
print("10+20")
# Out:
# 10+20

# %%
x=15
print(x)
# Out:
# 15

# %%
name="liya"
print(name)
# Out:
# liya

# %%
print("name:"+name)
# Out:
# name:liya

# %%
x=5
x=10
print(x)
# Out:
# 10

# %%
a=2
b=5
c=a+b
print(c)
# Out:
# 7

# %%
print(a)
# Out:
# 2

# %%
age=22
mark=70.4
name="liya"
name=input("enter name")
age=int(input("entrer age"))
mark=float(input("enter mark"))
print(type(name))
print(type(age))
print(type(mark))
# Out:
# enter nameliya
# entrer age20
# enter mark67
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
a = input("enter first number:")
b = input("enter second number:")
sum = a + b
print( sum )

# %%
a = input("enter first number:")
b = input("enter second number:")
sum = a + b
print( sum )

# %%
a = input("enter first number:")
b = input("enter second number:")
sum = a + b
print( sum )

# %%
side = float(input("enter the side of square:"))
area=side * side
print("area of the square=",area)
# Out:
# enter the side of square:4
# area of the square= 16.0

# %%
base=float(input("enter the base:"))
height=float(input("enter the height:"))
area=(base*height)/2
print("area of the traingle=",area)
# Out:
# enter the base:3
# enter the height:6
# area of the traingle= 9.0

# %%
principal=float(input("enter the principal amount:"))
years=float(input("enter the number ofyears:"))
rate=float(input("enter the rate of interest:"))
simple_interest=(principal*years*rate)/100
print("simple interest=",simple_interest)
# Out:
# enter the principal amount:19887
# enter the number ofyears:3
# enter the rate of interest:5638
# simple interest= 3363687.18

# %%
num=int(input("enter an integer:"))
print("previous number=",num-1)
print("next number=",num+1)
# Out:
# enter an integer:3
# previous number= 2
# next number= 4

# %%
a=float(input("enter the first number:"))
b=float(input("enter the second number:"))
print("sum=",a+b)
print("diffrence=",a-b)
print("product=",a*b)
# Out:
# enter the first number:3
# enter the second number:4
# sum= 7.0
# diffrence= -1.0
# product= 12.0

# %%
a=float(input("enter the first number:"))
b=float(input("enter the second number:"))
print("qoutient=",a//b)
print("reminder=",a%b)
# Out:
# enter the first number:4
# enter the second number:7
# qoutient= 0.0
# reminder= 4.0

# %%
r=float(input("enter the radius:"))
area=3.14*r*r
print("area of circle",area)
# Out:
# enter the radius:4
# area of circle 50.24

# %%
a=float(input("enter the first number:"))
b=float(input("enter the second number:"))
c=float(input("enter the third number:"))
average=(a+b+c)/3
print("avaerage",average)
# Out:
# enter the first number:3
# enter the second number:6
# enter the third number:8
# avaerage 5.666666666666667

# %%
celsius=float(input("enter temparature in celsius:"))
fahrenheit=(celsius*9/5)+32
print("temparature in fahrenheit=",fahrenheit)
# Out:
# enter temparature in celsius:4
# temparature in fahrenheit= 39.2

# %%
n=int(input("enter a number:"))
if n>100:
    print("number is greater than 100")
else:
    print("number is not graeter")
# Out:
# enter a number:56
# number is not graeter

# %%
n=int(input("enter a number:"))
if n>=0:
    print("positive")
else:
    print("negative")
# Out:
# enter a number:5
# positive

# %%
a=int(input("enter 1st number:"))
b=int(input("enter 2nd number:"))
if a==b:
    print("equal")
else:
    print("not equal")
# Out:
# enter 1st number:3
# enter 2nd number:5
# not equal

# %%
n=int(input("enter a number:"))
if n%2==0:
    print("even")
else:
    print("odd")
# Out:
# enter a number:4
# even

# %%
a=int(input("enter 1st number:"))
b=int(input("enter 2nd number:"))
if a>b:
    print(a,"is biggest")
else:
    print(b,"is biggest")
# Out:
# enter 1st number:3
# enter 2nd number:7
# 7 is biggest

# %%
age=int(input("enter your age:"))
if age>=18:
    print("eligible to vote")
    else:
    print("not eligible to vaote")
# Out:
#   File "<ipython-input-16-192a0c8dbd50>", line 4
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
age=int(input("enter your age:"))
if age>=18:
    print("eligible to vote")
else:
    print("not eligible to vaote")
# Out:
# enter your age:76
# eligible to vote

# %%
n=int(input("enter a number"))
if n%5==0:
    print("divisible by 5")
else:
    print("not divisible by 5")
# Out:
# enter a number4
# not divisible by 5
